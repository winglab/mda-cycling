# %%
import sqlite3
import requests
import pandas as pd
from datetime import datetime

# %%
## Function to write the data as a database
def data_to_sqlite():

    ## Collect the BASE URL
    base_url = "https://opendata.apps.mow.vlaanderen.be/fietstellingen/"
    db_name = "fietstellingen.db"

    ## Connect to (or create) the SQLite database
    conn = sqlite3.connect(db_name)

    ## give the date ranges
    dates = pd.date_range(start='2019-08-01', end=datetime.today(), freq='MS')
    col_names = ["Site_ID", "Direction", "Modus", "Start_Time", "End_Time", "Count"]

    first_run = True

    for date in dates:
        file_name = f"data-{date.strftime('%Y-%m')}.csv"
        file_url = base_url + file_name

        response = requests.head(file_url)
        if response.status_code == 200:
            print(f"Processing {file_name}...")
            try:
                df = pd.read_csv(file_url, sep=',', header=None, names=col_names, low_memory=False)

                ## Apply the grammar tags
                df['Site_ID'] = df['Site_ID'].astype(str).apply(lambda x: f"Location_Tag_{x}")

                ## Write to SQLite
                mode = 'replace' if first_run else 'append'
                df.to_sql('traffic_counts', conn, if_exists=mode, index=False)
                first_run = False

            except Exception as e:
                print(f"Error on {file_name}: {e}")

    conn.close()

# %%
data_to_sqlite()
# Out:
# Processing data-2019-08.csv...
# Processing data-2019-09.csv...
# Processing data-2019-10.csv...
# Processing data-2019-11.csv...
# Processing data-2019-12.csv...
# Processing data-2020-01.csv...
# Processing data-2020-02.csv...
# Processing data-2020-03.csv...
# Processing data-2020-04.csv...
# Processing data-2020-05.csv...
# Processing data-2020-06.csv...
# Processing data-2020-07.csv...
# Processing data-2020-08.csv...
# Processing data-2020-09.csv...
# Processing data-2020-10.csv...
# Processing data-2020-11.csv...
# Processing data-2020-12.csv...
# Processing data-2021-01.csv...
# Processing data-2021-02.csv...
# Processing data-2021-03.csv...
# Processing data-2021-04.csv...
# Processing data-2021-05.csv...
# Processing data-2021-06.csv...
# Processing data-2021-07.csv...
# Processing data-2021-08.csv...
# Processing data-2021-09.csv...
# Processing data-2021-10.csv...
# Processing data-2021-11.csv...
# Processing data-2021-12.csv...
# Processing data-2022-01.csv...
# Processing data-2022-02.csv...
# Processing data-2022-03.csv...
# Processing data-2022-04.csv...
# Processing data-2022-05.csv...
# Processing data-2022-06.csv...
# Processing data-2022-07.csv...
# Processing data-2022-08.csv...
# Processing data-2022-09.csv...
# Processing data-2022-10.csv...
# Processing data-2022-11.csv...
# Processing data-2022-12.csv...
# Processing data-2023-01.csv...
# Processing data-2023-02.csv...
# Processing data-2023-03.csv...
# Processing data-2023-04.csv...
# Processing data-2023-05.csv...
# Processing data-2023-06.csv...
# Processing data-2023-07.csv...
# Processing data-2023-08.csv...
# Processing data-2023-09.csv...
# Processing data-2023-10.csv...
# Processing data-2023-11.csv...
# Processing data-2023-12.csv...
# Processing data-2024-01.csv...
# Processing data-2024-02.csv...
# Processing data-2024-03.csv...
# Processing data-2024-04.csv...
# Processing data-2024-05.csv...
# Processing data-2024-06.csv...
# Processing data-2024-07.csv...
# Processing data-2024-08.csv...
# Processing data-2024-09.csv...
# Processing data-2024-10.csv...
# Processing data-2024-11.csv...
# Processing data-2024-12.csv...
# Processing data-2025-01.csv...
# Processing data-2025-02.csv...
# Processing data-2025-03.csv...
# Processing data-2025-04.csv...
# Processing data-2025-05.csv...
# Processing data-2025-06.csv...
# Processing data-2025-07.csv...
# Processing data-2025-08.csv...
# Processing data-2025-09.csv...
# Processing data-2025-10.csv...
# Processing data-2025-11.csv...
# Processing data-2025-12.csv...
# Processing data-2026-01.csv...
# Processing data-2026-02.csv...
# Processing data-2026-03.csv...
# Processing data-2026-04.csv...
# Processing data-2026-05.csv...
# Historical data successfully stored in fietstellingen.db
